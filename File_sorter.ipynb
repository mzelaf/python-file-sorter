# %% [markdown]
# # Automated File Sorter in File Explorer

# %%
import os, shutil

# %%
path = input("Enter the folder path to sort: ").strip()
if not path.endswith("/"):
    path += "/"
# Out:
# Enter the folder path to sort:  D:\Python File Project\File sorter

# %%
 file_name = os.listdir(path)

# %%
folder_names = ['csv files', 'png files', 'text files']

for loop in range (0,3):
     if not os.path.exists(path + folder_names[loop]):
         print(path + folder_names[loop])
         os.makedirs(path + folder_names[loop])

for file in file_name:
    if ".csv" in file and not os.path.exists(path +"csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".png" in file and not os.path.exists(path +"png files/" + file):
        shutil.move(path + file, path + "png files/" + file)
    elif ".txt" in file and not os.path.exists(path +"text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
# Out:
# D:\Python File Project\File sorter/csv files
# D:\Python File Project\File sorter/png files
# D:\Python File Project\File sorter/text files
